# %%
# !git clone https://github.com/rab306/generative-models-comparison.git
# Out:
# Cloning into 'generative-models-comparison'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 258 (delta 30), reused 30 (delta 15), pack-reused 211 (from 1)
# Receiving objects: 100% (258/258), 139.65 KiB | 2.29 MiB/s, done.
# Resolving deltas: 100% (174/174), done.

# %%
# %cd ./generative-models-comparison
# Out:
# /kaggle/working/generative-models-comparison

# %%
# !pip install -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 3.3 MB/s eta 0:00:00

# %%
# BCE loss Experiment
# !python src/train_vae.py --vae_latent_dim 64 --vae_beta 1.0 --epochs_vae 100
# Out:
# ⚙ Overriding VAE_BETA: 1.0
# ⚙ Overriding VAE_LATENT_DIM: 64
# ⚙ Overriding EPOCHS_VAE: 100
#
# 📋 Configuration Summary:
#    Device: cuda
#    Random Seed: 42
#    Results Dir: /kaggle/working/generative-models-comparison/results
#
#
# ...
# 🚀 Starting VAE Training on cuda
# ...
#    Batch Size:      64
#    Latent Dim:      64
#    KL Beta:         1.0
#    Epochs:          100
#    Learning Rate:   0.001
#    Num Workers:     0
# ...
#
#    📄 Config saved to: /kaggle/working/generative-models-comparison/results/vae_run_20260313_231039/config.json
#    Training samples:   50,000
#    Validation samples: 10,000
#
#    Total Parameters:   2,108,163
#    Trainable Params:   2,108,163
#
#
# Epoch 001 | Train: 1916.801 (Recon: 1891.026, KL: 25.774, Ratio: 0.014) | Val: 1864.624
#    📸 Samples saved to: /kaggle/working/generative-models-comparison/results/vae_run_20260313_231039/samples/epoch_001.png
#    ⭐ New best model! (Val Loss: 1864.624)
#
# ...

# %%
# BCE visualization with beta = 1
# %run src/loss_visualizations.py --model vae
# Out:
# ✅ Found VAE runs in: results/vae_run*
#
# 📊 VAE Loss History
#    Epochs: 100
#    Final Train Loss: 1813.5073
#    Final Val Loss: 1818.3442
#    Final KL/Recon Ratio: 0.0253
# ✅ VAE plot saved to: results/vae_run_20260313_231039/loss_curves.png

# %%
# !python src/evaluation.py --model vae
# Out:
# 🔍 Evaluating VAE...
# ✅ Found VAE runs in: results/vae_run*
#    Run: results/vae_run_20260313_231039
#
# ...
# 🔬 VAE QUANTITATIVE EVALUATION
# ...
#
# 🔄 Loading VAE model...
#   ✅ Loaded VAE from epoch 90
#
# 🖼️  Loading real CIFAR-10 images...
#   Loading 2000 real CIFAR-10 images...
#   ✅ Loaded 2000 real images
#
# 🎨 Generating VAE samples...
#   Generating 500 VAE samples...
#   ✅ Generated 500 samples
#
# 📊 Computing metrics...
#   Computing FID...
#   Computing Inception Score...
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
#
# ...
# 📈 VAE RESULTS
# ...
# FID Score:       206.19 (lower is better)
# Inception Score: 2.8449 ± 0.3615 (higher is better)
# ...
#
# ✅ Metrics saved to: results/vae_run_20260313_231039/evaluation_metrics.csv
#
# ✨ Evaluation complete!

# %%
# MSE loss Experiment
# !python src/train_vae.py --vae_latent_dim 64 --vae_beta 1.0 --epochs_vae 100
# Out:
# ⚙ Overriding VAE_BETA: 1.0
# ⚙ Overriding VAE_LATENT_DIM: 64
# ⚙ Overriding EPOCHS_VAE: 100
#
# 📋 Configuration Summary:
#    Device: cuda
#    Random Seed: 42
#    Results Dir: /kaggle/working/generative-models-comparison/results
#
#
# ...
# 🚀 Starting VAE Training on cuda
# ...
#    Batch Size:      64
#    Latent Dim:      64
#    KL Beta:         1.0
#    Epochs:          100
#    Learning Rate:   0.001
#    Num Workers:     0
# ...
#
#    📄 Config saved to: /kaggle/working/generative-models-comparison/results/vae_run_20260313_195710/config.json
#    Training samples:   50,000
#    Validation samples: 10,000
#
#    Total Parameters:   2,108,163
#    Trainable Params:   2,108,163
#
#
# Epoch 001 | Train: 109.887 (Recon: 95.927, KL: 13.960, Ratio: 0.146) | Val: 87.190
#    📸 Samples saved to: /kaggle/working/generative-models-comparison/results/vae_run_20260313_195710/samples/epoch_001.png
#    ⭐ New best model! (Val Loss: 87.190)
#
# ...

# %%
# MSE visualization with beta = 1
# %run src/loss_visualizations.py --model vae
# Out:
# ✅ Found VAE runs in: results/vae_run*
#
# 📊 VAE Loss History
#    Epochs: 100
#    Final Train Loss: 72.8904
#    Final Val Loss: 73.6592
#    Final KL/Recon Ratio: 0.4593
# ✅ VAE plot saved to: results/vae_run_20260313_195710/loss_curves.png

# %%
# !python src/evaluation.py --model vae
# Out:
# 🔍 Evaluating VAE...
# ✅ Found VAE runs in: results/vae_run*
#    Run: results/vae_run_20260313_195710
#
# ...
# 🔬 VAE QUANTITATIVE EVALUATION
# ...
#
# 🔄 Loading VAE model...
#   ✅ Loaded VAE from epoch 99
#
# 🖼️  Loading real CIFAR-10 images...
#   Loading 2000 real CIFAR-10 images...
#   ✅ Loaded 2000 real images
#
# 🎨 Generating VAE samples...
#   Generating 500 VAE samples...
#   ✅ Generated 500 samples
#
# 📊 Computing metrics...
#   Computing FID...
#   Computing Inception Score...
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
#
# ...
# 📈 VAE RESULTS
# ...
# FID Score:       243.01 (lower is better)
# Inception Score: 2.3042 ± 0.1594 (higher is better)
# ...
#
# ✅ Metrics saved to: results/vae_run_20260313_195710/evaluation_metrics.csv
#
# ✨ Evaluation complete!

# %%
# DDPM Experiments with 1000 timesteps
# !python src/train_ddpm.py --epochs_ddpm 100
# Out:
# ⚙ Overriding EPOCHS_DDPM: 100
#
# 📋 Configuration Summary:
#    Device: cuda
#    Random Seed: 42
#    Results Dir: /kaggle/working/generative-models-comparison/results
#
#
# ...
# 🚀 Starting DDPM Training on cuda
# ...
#    Batch Size:      64
#    Timesteps:       1000
#    Schedule:        cosine
#    Epochs:          100
#    Learning Rate:   0.0002
#    Num Workers:     0
# ...
#
#    📄 Config saved to: /kaggle/working/generative-models-comparison/results/ddpm_run20260313_204311/config.json
#    Training samples:   50,000
#    Test samples:       10,000
#
#    🆕 No checkpoint found, starting fresh
#
#    Total Parameters:   5,589,635
#    Trainable Params:   5,589,635
#
#
#    🎲 Fixed noise created for consistent grid sampling
#
# Epoch 001 | Train: 0.1070 | Val: 0.0788 | Val Time: 6.3s | LR: 2.00e-04 | Total: 71.6s
#    ⭐ New best model! (Validation Loss: 0.0788)
#
# Epoch 002 | Train: 0.0743 | Val: 0.0711 | Val Time: 6.3s | LR: 2.00e-04 | Total: 75.2s
# ...

# %%
# %run src/loss_visualizations.py --model ddpm
# Out:
# ✅ Found DDPM runs in: results/ddpm_run*
#
# 📊 DDPM Loss History
#    Epochs: 100
#    Final Train Loss: 0.0571
#    Final Val Loss: 0.0591
#    Avg Epoch Time: 75.5s
#    Avg Val Time: 6.5s (8.6% of epoch)
# ✅ DDPM plot saved to: results/ddpm_run20260313_204311/loss_curves.png

# %%
# !python src/evaluation.py --model ddpm
# Out:
# 🔍 Evaluating DDPM...
# ✅ Found DDPM runs in: results/ddpm_run*
#    Run: results/ddpm_run20260313_204311
#
# ...
# 🔬 DDPM QUANTITATIVE EVALUATION
# ...
#
# 🔄 Loading DDPM model...
#   ✅ Loaded DDPM from epoch 91
#
# 🖼️  Loading real CIFAR-10 images...
#   Loading 2000 real CIFAR-10 images...
#   ✅ Loaded 2000 real images
#
# 🎨 Generating DDPM samples...
#    (This takes ~30 minutes, please be patient...)
#   Generating 500 DDPM samples (this may take a while)...
#   ✅ Generated 500 samples in 4.6 minutes
#
# 📊 Computing metrics...
#   Computing FID...
#   Computing Inception Score...
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
#
# ...
# 📈 DDPM RESULTS
# ...
# FID Score:       75.16 (lower is better)
# Inception Score: 4.3667 ± 0.4569 (higher is better)
# Generation Time: 4.6 minutes for 500 images
# ...
#
# ...

# %%
# DDPM Experiments with 400 timesteps
# !python src/train_ddpm.py --epochs_ddpm 100 --ddpm_timesteps 400
# Out:
# ⚙ Overriding EPOCHS_DDPM: 100
# ⚙ Overriding DDPM_TIMESTEPS: 400
#
# 📋 Configuration Summary:
#    Device: cuda
#    Random Seed: 42
#    Results Dir: /kaggle/working/generative-models-comparison/results
#
#
# ...
# 🚀 Starting DDPM Training on cuda
# ...
#    Batch Size:      64
#    Timesteps:       400
#    Schedule:        cosine
#    Epochs:          100
#    Learning Rate:   0.0002
#    Num Workers:     0
# ...
#
#    📄 Config saved to: /kaggle/working/generative-models-comparison/results/ddpm_run20260313_170534/config.json
#    Training samples:   50,000
#    Test samples:       10,000
#
#    🆕 No checkpoint found, starting fresh
#
#    Total Parameters:   5,589,635
#    Trainable Params:   5,589,635
#
#
#    🎲 Fixed noise created for consistent grid sampling
#
# Epoch 001 | Train: 0.1057 | Val: 0.0773 | Val Time: 6.3s | LR: 2.00e-04 | Total: 71.9s
#    ⭐ New best model! (Validation Loss: 0.0773)
#
# Epoch 002 | Train: 0.0746 | Val: 0.0696 | Val Time: 6.2s | LR: 2.00e-04 | Total: 73.8s
# ...

# %%
# %run src/loss_visualizations.py --model ddpm
# Out:
# ✅ Found DDPM runs in: results/ddpm_run*
#
# 📊 DDPM Loss History
#    Epochs: 100
#    Final Train Loss: 0.0570
#    Final Val Loss: 0.0566
#    Avg Epoch Time: 74.2s
#    Avg Val Time: 6.3s (8.4% of epoch)
# ✅ DDPM plot saved to: results/ddpm_run20260313_170534/loss_curves.png

# %%
# !python src/evaluation.py --model ddpm
# Out:
# 🔍 Evaluating DDPM...
# ✅ Found DDPM runs in: results/ddpm_run*
#    Run: results/ddpm_run20260313_170534
#
# ...
# 🔬 DDPM QUANTITATIVE EVALUATION
# ...
#
# 🔄 Loading DDPM model...
#   ✅ Loaded DDPM from epoch 66
#
# 🖼️  Loading real CIFAR-10 images...
#   Loading 2000 real CIFAR-10 images...
#   ✅ Loaded 2000 real images
#
# 🎨 Generating DDPM samples...
#    (This takes ~30 minutes, please be patient...)
#   Generating 500 DDPM samples (this may take a while)...
#   ✅ Generated 500 samples in 1.7 minutes
#
# 📊 Computing metrics...
#   Computing FID...
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100%|███████████████████████████████████████| 91.2M/91.2M [00:00<00:00, 196MB/s]
#   Computing Inception Score...
# ...
